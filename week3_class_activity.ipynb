# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("images/test_image.jpg", cv2.IMREAD_UNCHANGED)
img.shape
# Out:
# (3840, 5760, 3)

# %%
bgr_image = img[...,0:3]
alpha_image = img[...,-1]
rgb_image = cv2.cvtColor(bgr_image, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_image); plt.title("RGB");

# %%
plt.imshow(alpha_image, cmap='gray'); plt.title("Alpha");

# %%
img = cv2.imread("images/test_image.jpg", cv2.IMREAD_UNCHANGED)
img.shape
# Out:
# (3840, 5760, 3)

# %%
bgr_image = img[...,0:3]
alpha_image = img[...,-1]
